# %%
import pandas as pd
import numpy as np
import pickle
from collections import Counter, defaultdict
import re
from scipy import spatial
#from textblob import TextBlob
import spacy
import neuralcoref
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: spacy.morphology.Morphology size changed, may indicate binary incompatibility. Expected 104 from C header, got 112 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: spacy.vocab.Vocab size changed, may indicate binary incompatibility. Expected 96 from C header, got 104 from PyObject
#   return f(*args, **kwds)

# %%
# Uncomment below if running for first time. 
# Setup nltk corpora path and Google Word2Vec location
#google_vec_file = 'data/GoogleNews-vectors-negative300.bin'
#word2vec = gensim.models.KeyedVectors.load_word2vec_format(google_vec_file, binary=True)
#pickle.dump(word2vec, open("data/word2vec_google.pkl", 'wb'))

# %%
#import gensim.downloader as api
#wv = api.load('word2vec-google-news-300')

# %%
# Loading opinion lexicon
neg_file = open("data/opinion-lexicon-English/negative-words.txt",encoding = "ISO-8859-1")
pos_file = open("data/opinion-lexicon-English/positive-words.txt",encoding = "ISO-8859-1")
neg = [line.strip() for line in neg_file.readlines()]
pos = [line.strip() for line in pos_file.readlines()]
opinion_words = neg + pos

# %%
dataset = pd.read_csv('./data/ms_review_final.csv')
dataset.head(5)
# Out:
#          museum                      rating  \
# 0  Adams Museum  ui_bubble_rating bubble_50
# 1  Adams Museum  ui_bubble_rating bubble_50
# 2  Adams Museum  ui_bubble_rating bubble_50
# 3  Adams Museum  ui_bubble_rating bubble_40
# 4  Adams Museum  ui_bubble_rating bubble_50
#
#                                                title  \
# 0  Took our flat land cousins to the Adams Museum...
# 1                              Black Hills Gold Rush
# 2  Make This Your First Stop To Learn Deadwood’s ...
# 3                      If you have time to waste....
# 4                     Days Of Old West's Glory Days.
#
#                                              content        review_date  \
# 0  This excellent museum is a hidden gem. Tells t...    January 8, 2020
# 1  No better way to familiarize yourself with the...    January 7, 2020
# 2  This is a fabulous small museum on the history...  November 21, 2019
# 3  This place has great history about Deadwood. L...  November 18, 2019
# 4  Adams Museum has it all to see. The first mini...   November 5, 2019
#
#                     experienced_date             user_location
# 0  Date of experience: December 2019               Albuquerque
# 1  Date of experience: November 2019             Austin, Texas
# 2      Date of experience: June 2019  San Fernando, California
# 3  Date of experience: November 2019             Spring, Texas
# 4   Date of experience: October 2019                       NaN

# %%
dataset['museum'].value_counts().tail(20)
# Out:
# Museo dell'Ara Pacis                       105
# Monterey Museum of Art - Pacific Street    102
# Little Prince Museum                       102
# Museu del Modernisme                        99
# Kyoto National Museum                       98
# New Hampshire Boat Museum                   95
# Bagatti Valsecchi Museum                    94
# Martin Auto Museum                          92
# Brno Technical Museum                       87
# Armed Forces Museum                         85
# Museo dell'Olio d'Oliva                     83
# Museo di Storia Naturale                    82
# Geppi's Entertainment Museum                74
# Fukui Dinosaur Museum                       64
# Vasterbottens Museum                        60
# Villa Zorayda Museum                        54
# Fundacio Joan Miro                          41
# Mayborn Museum Complex                      40
# New Zealand Maritime Museum                 36
# Museum Mile                                 31
# Name: museum, dtype: int64

# %%
mini_data = dataset[dataset['museum'] == "Georgia O'Keeffe Museum"]
#mini_data = dataset[dataset['museum'] == "Armed Forces Museum"]
mini_data.head()
# Out:
#                          museum                      rating  \
# 185440  Georgia O'Keeffe Museum  ui_bubble_rating bubble_50
# 185441  Georgia O'Keeffe Museum  ui_bubble_rating bubble_50
# 185442  Georgia O'Keeffe Museum  ui_bubble_rating bubble_40
# 185443  Georgia O'Keeffe Museum  ui_bubble_rating bubble_50
# 185444  Georgia O'Keeffe Museum  ui_bubble_rating bubble_50
#
#                                         title  \
# 185440              Loved the O’Keeffe museum
# 185441                     A wonderful place.
# 185442                         Learned a lot!
# 185443                   Left me wanting more
# 185444  Perfect Amount of information and art
#
#                                                   content       review_date  \
# 185440  Small but has a lot of wonderful art. Also goo...  January 27, 2020
# 185441  I would compare this with the Van Gogh museum ...  January 23, 2020
# 185442  Did not know what to expect, but learned a lot...  January 23, 2020
# 185443  My only complaint is the vast amount of the ar...  January 21, 2020
# 185444  This is in no way all her art but there is eno...  January 19, 2020
#
#                         experienced_date          user_location
# 185440  Date of experience: January 2020           Maui, Hawaii
# 185441  Date of experience: January 2020  Egg Harbor, Wisconsin
# 185442  Date of experience: January 2020  Washougal, Washington
# 185443  Date of experience: January 2020  Princeton, New Jersey
# 185444  Date of experience: January 2020    Scottsdale, Arizona

# %%
nlp = spacy.load("en_core_web_md")

# %%
neuralcoref.add_to_pipe(nlp, greedyness= 0.4)

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

spacy_stopwords.extend(["museum", "attractions", "ambience", "price", "service"])

# %% [markdown]
# Coreference resolution in reviews

# %%
def replace_pronouns(text):
    doc = nlp(text)
    resolved_text = doc._.coref_resolved
    return resolved_text

# %% [markdown]
# Sentence Tokenization

# %%
def split_sentence(text):
    """
    Splits review into a list of sentences using spacy's sentence parser
    """
    doc = nlp(text)
    bag_sentences = list(doc.sents)
    return bag_sentences

# %% [markdown]
# Remove special characters

# %%
def remove_special_char(sentence):
    clarified_sent = re.sub(r"[^a-zA-Z0-9.',:;?]+", ' ', sentence)
    return clarified_sent

# %% [markdown]
# Extract aspects and corresponding sentiments

# %%
def feature_sentiment(text):
    '''
    input: dictionary and sentence
    function: appends dictionary with new features if the feature did not exist previously,
              then updates sentiment to each of the new or existing features
    output: updated dictionary
    '''
    sent_dict = Counter()
    sentence = nlp(text)
    debug = 0
    for token in sentence:
    #    print(token.text,token.dep_, token.head, token.head.dep_)
        # check if the word is an opinion word, then assign sentiment
        if token in spacy_stopwords:
            continue
        if token.lemma_ in opinion_words:
            sentiment = 1 if token.lemma_ in pos else -1
            # if target is an adverb modifier (i.e. pretty, highly, etc.)
            # but happens to be an opinion word, ignore and pass
            if (token.dep_ == "advmod"):
                continue
            elif (token.dep_ == "amod"):
                sent_dict[token.head.lemma_] += sentiment
            # for opinion words that are adjectives, adverbs, verbs...
            else:
                for child in token.children:
                    # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                    # This could be better updated for modifiers that either positively or negatively emphasize
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.lemma_ in opinion_words):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if child.dep_ == "neg":
                        sentiment *= -1
                for child in token.children:
                    # if verb, check if there's a direct object
                    if (token.pos_ == "VERB") & (child.dep_ == "dobj"):                        
                        sent_dict[child.lemma_] += sentiment
                        # check for conjugates (a AND b), then add both to dictionary
                        subchildren = []
                        conj = 0
                        for subchild in child.children:
                            if subchild.text == "and":
                                conj=1
                            if (conj == 1) and (subchild.text != "and"):
                                subchildren.append(subchild.lemma_)
                                conj = 0
                        for subchild in subchildren:
                            sent_dict[subchild] += sentiment

                # check for negation
                for child in token.head.children:
                    noun = ""
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.lemma_ in opinion_words):
                        sentiment *= 1.5
                    # check for negation words and flip the sign of sentiment
                    if (child.dep_ == "neg"): 
                        sentiment *= -1
                
                # check for nouns
                for child in token.head.children:
                    noun = ""
                    if (child.pos_ == "NOUN") and (child.lemma_ not in sent_dict):
                        noun = child.lemma_
                        # Check for compound nouns
                        for subchild in child.children:
                            if subchild.dep_ == "compound":
                                noun = subchild.lemma_ + " " + noun
                        sent_dict[noun] += sentiment
                    debug += 1
    
    copy_sent_dict  = {}
    
    for key, value in sent_dict.items():
        if key not in spacy_stopwords:
            copy_sent_dict[key] = value

    return copy_sent_dict

# %% [markdown]
# Assign extracted terms to broader aspects

# %%
def assign_term_to_aspect(aspect_sent, terms_dict, sent_dict):
    '''
    function: takes in a sentiment dictionary and appends the aspect dictionary
    inputs: sent_dict is a Counter in the form Counter(term:sentiment value)
            aspect_sent is total sentiment tally
            terms_dict is dict with individual aspect words associated with sentiment
    output: return two types of aspect dictionaries: 
            updated terms_dict and aspect_sent
    '''
    aspects = ['ambience', 'attractions', 'price', 'service']
    
    
    
    # First, check word2vec
    # Note: the .split() is used for the term because word2vec can't pass compound nouns
    for term in sent_dict:
        try:
            # The conditions for when to use the NB classifier as default vs word2vec
            if check_similarity(aspects, term.split()[-1]):
                terms_dict[check_similarity(aspects, term.split()[-1])][term] += sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent[check_similarity(aspects, term.split()[-1])]["pos"] += sent_dict[term]
                else:
                    aspect_sent[check_similarity(aspects, term.split()[-1])]["neg"] += abs(sent_dict[term])

            # if unable to classify via NB or word2vec, then put them in misc. bucket
            else:
                terms_dict["misc"][term] += sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent["misc"]["pos"] += sent_dict[term]
                else:
                    aspect_sent["misc"]["neg"] += abs(sent_dict[term])
        except:
            print(term, "not in vocab")
            continue
    return aspect_sent, terms_dict

# %% [markdown]
# Word2Vec for aspect similarity classification

# %%
def check_similarity(aspects, word):
    '''
    checks for word2vec similarity values between category word and the term
    returns most similar word
    '''
    similarity = []
    word = nlp.vocab[word].vector
    cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)
    for aspect in aspects:
        aspect = nlp.vocab[aspect].vector
        similarity.append(cosine_similarity(aspect, word))
    # set threshold for max value
    if max(similarity) > 0.30:
        return aspects[np.argmax(similarity)]
    else:
        return None

# %% [markdown]
# Get aspect-sentiment pairs

# %%
def classify_and_sent(sentence, aspect_sent, terms_dict):
    '''
    note: aspect_dict is a parent dictionary with all the aspects
    input: sentence & aspect dictionary, which is going to be updated
    output: updated aspect dictionary
    '''
    
    # get aspect names and their sentiment in a dictionary form
    sent_dict = feature_sentiment(sentence)
    
    # try to categorize the aspect names into the 4 aspects in aspect_dict
    aspect_sent, terms_dict = assign_term_to_aspect(aspect_sent, terms_dict, sent_dict)
    return aspect_sent, terms_dict

# %% [markdown]
# NLP pipeline

# %%
def review_pipe(review, aspect_sent, terms_dict):
    review = replace_pronouns(review)
    sentences = split_sentence(review)
    for sentence in sentences:
        sentence = remove_special_char(str(sentence))
        aspect_sent, terms_dict = classify_and_sent(sentence.lower(), aspect_sent, terms_dict)
    return aspect_sent, terms_dict

# %%
sentence= "I came here with my friends on a Tuesday night. The sushi here is amazing. Our waiter was very helpful, but the music was terrible."
feature_sentiment(sentence)
# Out:
# {'sushi': 1, 'waiter': 1, 'music': -1}

# %%
terms_dict={'ambience':Counter(), 'attractions':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
aspect_sent={'ambience':Counter(), 'attractions':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}

# %%
review = "Our waiter was not very helpful, and the music was terrible."
review_pipe(review, aspect_sent, terms_dict)
# Out:
# ({'ambience': Counter({'neg': 1}),
#   'attractions': Counter(),
#   'price': Counter(),
#   'service': Counter(),
#   'misc': Counter({'neg': 1})},
#  {'ambience': Counter({'music': -1}),
#   'attractions': Counter(),
#   'price': Counter(),
#   'service': Counter(),
#   'misc': Counter({'waiter': -1})})

# %%
terms_dict={'ambience':Counter(), 'attractions':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}
aspect_sent={'ambience':Counter(), 'attractions':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}

# %%
service = nlp.vocab['music'].vector

# %%
cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

# %%
waiter = nlp.vocab['ambience'].vector

# %%
cosine_similarity(waiter, service)
# Out:
# 0.34634047746658325

# %%
count = 0
for review in mini_data["content"]:
    if count % 500 == 0:
        print(count)
    aspect_sent, terms_dict = review_pipe(review, aspect_sent, terms_dict)
    count += 1
# Out:
# 0
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500

# %%
aspect_sent
# Out:
# {'ambience': Counter({'neg': 208.25, 'pos': 1556.75}),
#  'attractions': Counter({'pos': 1312.0, 'neg': 154.75}),
#  'price': Counter({'pos': 462.0, 'neg': 131.0}),
#  'service': Counter({'pos': 5076.0, 'neg': 312.25}),
#  'misc': Counter({'pos': 5555.9375, 'neg': 838.5})}

# %%
terms_dict
# Out:
# {'ambience': Counter({'coffee break': -1,
#           'place': 180.0,
#           'appreciation': 33,
#           'crowd': 1,
#           'fine': -1,
#           'look': 20,
#           'way': 103,
#           'fear': -1,
#           'space': 45,
#           'sense': 18,
#           'diversity': 0.75,
#           'humor': 2,
#           'life': 110.0,
#           'food': 6,
#           'fun': 15.5,
#           'plenty': 5.25,
#           'atmosphere': 5,
#           'feel': 8,
#           'flow': 7,
#           'inspiration': 74,
#           'artistry': 3,
#           'creativity': 3,
#           'pleasure': 14,
#           'surprise': 18,
#           'afternoon': 16,
#           'lot': 39.75,
#           'contrast': 5,
#           'friday evening': 1,
#           'perspective': 24,
#           'idea': 23,
#           'lighting': 7,
#           'background': 28,
#           'negative': -3,
#           'rattle': -1,
#           'thought': -1,
#           'experiences': 1,
#           'fact': 15,
#           'sun': 0,
#           'effect': 3,
#           'love': 91.75,
#           'personality': 3,
#           'nature': 1,
#           'city night': 1,
#           'building': 36.5,
#           'peace': 6,
#           'thing': 52,
#           'dynamic': -1,
#           'minimalism': 1,
#           'desire': 2,
#           'delight': 17,
#           'lack': -18,
#           'combination': 5,
#           'overwhelming': 0,
#           'surface': 1,
#           'joy': 16.5,
#           'venue': 4,
#           'enjoyment': 12.5,
#           'spite': -4,
#           'room': 31.0,
#           'suspense': 1,
#           'heart': 0,
#           'museum building': 4,
#           'vibe': 0,
#           'reflective': 2,
#           'cold': -1,
#           'notion': -1.5,
#           'passion': 13,
#           'spirit': 10,
#           'influence': 1,
#           'change': 3,
#           'garden': 4,
#           'focus': 4,
#           'harmony': 1,
#           'juxtaposition': 6,
#           'floor': 0,
#           'manner': 4,
#           'compliment': 1,
#           'attitude': 1,
#           'pace': 0,
#           'growth transition': 1.5,
#           'outdoors': 1,
#           'staff love': 1,
#           'thrill': 4,
#           'complement': 2,
#           'aspect': 7,
#           'style': 8.5,
#           'concept': 2,
#           'scene': 1,
#           'art material': 1,
#           'old love': 1,
#           'break': 3,
#           'impact': 0,
#           'lifestyle': 2,
#           'conversation': 4,
#           'culture': 3,
#           'doubt': -4,
#           'mexico inspiration': 1,
#           'light': 4,
#           'relax': 1,
#           'feeling': -1,
#           'interior': 0,
#           'adobe building': 1,
#           'desk folk': 0,
#           'appreciate': 2.5,
#           'child inspiration': 1,
#           'theme': 3,
#           'isolation': 0,
#           'quiet': 2,
#           'abundance': 2,
#           'noise': -3,
#           'transition': 2,
#           'dark': -1,
#           'phenomenal': 1,
#           'substance': -1,
#           'patron': 3,
#           'memorable': 1,
#           'blend': 4,
#           'house': 10,
#           'acoustic': -2,
#           'brilliance': 1,
#           'material': 5,
#           'mixture': 3,
#           'year celebration': 1,
#           'little': 1,
#           'chance': 5,
#           'setting': 10,
#           'concentration': 3,
#           'opposite': 1,
#           'depth': 1,
#           'structure': 2,
#           'adams inspiration': 1,
#           'rest': 4.5,
#           'seating': 5,
#           'parking pay lot': 1,
#           'work inspiration': 1,
#           'expectation': 0,
#           'reflection': 4,
#           'charm': 2,
#           'matter': 2,
#           'activity': 2,
#           'spark': 1,
#           'environment': 5,
#           'mist': -4,
#           'outdoor': 1,
#           'smoke': -1,
#           'awe': 7,
#           'attraction downtown house': 1,
#           'warmth': -1,
#           'folk': -2,
#           'bar': 1,
#           'mind': 2,
#           'exposure': 1,
#           'bathroom break': -1,
#           'weather': 4,
#           'listening': 1,
#           'mood': 0,
#           'taste': -2,
#           'unfriendliness': 0,
#           'night': 3,
#           'ambience': 1,
#           'revival': 1,
#           'overabundance': -1,
#           'retreat': -2,
#           'potential': 1,
#           'emphasis': 2,
#           'composition': 0,
#           'passionate': 1,
#           'admiration': 3,
#           'escape': 1,
#           'chaos': -1,
#           'contentment': 1,
#           'retelling': 1,
#           'soul': 2,
#           'k life': 1,
#           'like': 1,
#           'opening': -1.5,
#           'aura': 1,
#           'intimacy': 6,
#           'lacking': -2,
#           'contemporary': 2,
#           'element': 1,
#           'zeitgeist': 1,
#           'breathing': -1,
#           'complex': -1,
#           "o'keeffe building": 1,
#           'loud': -1,
#           'realism': 1,
#           'sky': 1,
#           'excitement': 2,
#           'imagination': 3,
#           'museum house': 1,
#           'feast': 1,
#           "museum o'keeffe building": 1.5,
#           'impression': 3,
#           'simplicity': 2,
#           'intrigue': 1.5,
#           'present': 1,
#           'earth': 1,
#           'coffee': 1,
#           'patio': 2,
#           'interaction': 2,
#           'encounter': -1,
#           'spring school daughter break': -1,
#           'positive': 1,
#           'enthusiasm': 2,
#           'modernist': 1,
#           'dining': -1,
#           'celebration': 2,
#           'great': 2,
#           'decent': 1,
#           'possibility': -1,
#           'wife love': 2,
#           'tone': 0,
#           'level': 1,
#           'amazement': 3,
#           'surrounding': -1,
#           'comfort': 1,
#           'subject island matter': 1,
#           'wine': 1,
#           'ambiance': -1,
#           'observation': 1,
#           'evocative': 1,
#           'smell': -1,
#           'minimalist': 1,
#           'musuem space': 1,
#           'adulation': 1,
#           'profusion': 1,
#           'imagery': 1,
#           'impress': 1,
#           'dinner': 1,
#           'engaging': 1,
#           'surround': 1,
#           'rotation thing': 0,
#           'affair': 1,
#           'building complex': -1,
#           'style building': 1,
#           'longing': -2,
#           'tranquility': 1,
#           'ground': 2,
#           'mystery': -2,
#           'elegance': 1,
#           'beautiful': 1,
#           'force': 1,
#           'chamber': -1,
#           'creature comfort': 1,
#           'blending': -1,
#           'moment': 1,
#           'artist retreat': 0,
#           'brunch': 1,
#           'gallery friday night': 1,
#           'evening': 1,
#           'keeffe life': 1,
#           'keeffe georgia love': 0,
#           'ruin': -1,
#           'vision passion': 1,
#           'meal': 1}),
#  'attractions': Counter({'history': 51.5,
#           'life journey': 1,
#           'docent': 117.75,
#           'world': 1,
#           'beauty': 35.5,
#           'people': 17,
#           'visit': 263.25,
#           'tour': 184.5,
#           'trip': 42.75,
#           'docent tour': 10,
#           'trail ride': 1,
#           'treasure': 41.5,
#           'journey': 6,
#           'gem': 40,
#           'parking': -13,
#           'attraction': 21.5,
#           'drive': 5,
#           'entrance': 7,
#           'desert': -37.0,
#           'guide': 44,
#           'museum art visitor': -1,
#           'ride': 1,
#           'detour': 1,
#           'landscape': 35.5,
#           'city': 5,
#           'walk': 34.5,
#           'tourist': -3,
#           'stop': 42.5,
#           "go'keeffe museum": 1,
#           'town': 5,
#           'audio tour': 13,
#           'stroll': 2,
#           'canyon': -1,
#           'mexico desert': -1,
#           'spot': 9,
#           'tour guide': 4,
#           'couple': 8.5,
#           'audio guide': 2,
#           'stay': -1,
#           'area': 14.5,
#           'street': 1,
#           'go museum': 0,
#           'guest': 1,
#           'distance': 11,
#           'life history': 1,
#           'visitor': 9,
#           'camper': 1,
#           'downtown attraction': 2,
#           'destination': -1,
#           'guide tour': 1,
#           'museum amenity': 1,
#           'map': -1,
#           'small': 1,
#           'cityscape': 1,
#           'geography': 1,
#           'lunch': 5,
#           'seeing': 3,
#           'scenery': 16,
#           'cafe': 6,
#           'leave': 0,
#           'studio tour': 1.5,
#           'star': 0,
#           'art museum': 1,
#           'art guide': 1,
#           'tourist attraction': 1,
#           'downtown': 3,
#           'takeaway': 1,
#           'traveler': 2,
#           'backdrop': 2,
#           'restaurant': 7,
#           'architecture': 3.5,
#           'countryside': 2,
#           'outing': 2,
#           'sight': 0,
#           'southwest': 2.5,
#           'wonder': 9,
#           'tour bus': 1,
#           'bird': -1,
#           "life o'keefes journey": -1,
#           'hiking trail': 1,
#           'trail': 1,
#           'jewel': 3,
#           'glimpse': 3,
#           'hour tour': 2,
#           'courtyard': 1,
#           'shortage': -1,
#           'know desert': -1,
#           'panorama': 1,
#           'fascination': 4.5,
#           'getaway': 1,
#           'recreation': 1,
#           'artist museum': -2.5,
#           'country': 4,
#           'pilgrimage': 1,
#           'mountain desert': -1,
#           'rail': -2,
#           'audio ipad tour': 1,
#           'walking tour': 1,
#           'century': 1,
#           'sale people': 1,
#           'hill': -1,
#           'popularity': 1,
#           'hotel': 2,
#           'stranger': -1,
#           'audio app downloadable tour': 1,
#           'mexico landscape': 1,
#           'mountain': 1,
#           'hike': 1,
#           'audio self tour': 1,
#           'dearth': -1,
#           'scenic': 1,
#           'adventure': 2,
#           'street parking': 1,
#           'upscale': 1,
#           'pedernales landscape': 1,
#           'research tour': 1,
#           'spectacular': 1,
#           'bus': 1,
#           'amenity': 3.5,
#           'money attraction': 1,
#           'grandeur': 1,
#           'admire': 1,
#           'museum guide': -1.5,
#           'region': 1,
#           'weekend': -1,
#           'property': 1,
#           'land': 1,
#           'inn': 1,
#           'breakfast': 1,
#           'place museum': 1,
#           'day trip': -1,
#           'nm desert': -1,
#           'mexico resident': 1,
#           'art history': 1,
#           'explore': 1,
#           'house tour': 1,
#           'side visit': 1,
#           'exhibit area': 1,
#           'citizen': 0,
#           'drive hour trip': 1}),
#  'price': Counter({'size': 61.5,
#           'item': 40,
#           'son interest': -1,
#           'price': 46.0,
#           'museum store': 2,
#           'admission cost': 2.5,
#           'speed limit': -1,
#           'description': 8,
#           'value': 11,
#           'info': 9,
#           'worth': 5,
#           'pricing': 2,
#           'store': 23.5,
#           'quote': 7,
#           'interest': 1.5,
#           'fee': 7.25,
#           'e ticket': 1,
#           'gift': 9.5,
#           'deal': 30,
#           'admission fee': 2.75,
#           'review': 0,
#           'admission price': 5.75,
#           'bargain': 5,
#           'merchandise': 2,
#           'figure': 2,
#           'result': 0,
#           'term': 1,
#           'limit': -6,
#           'discount': -3,
#           'trend': -1,
#           'month': 1,
#           'arena size': -1,
#           'high': -1,
#           'tax': 1,
#           '13.00': 1,
#           'ticket': 2,
#           'pricey': -4,
#           'risk': -3,
#           'point': 5,
#           'supply': 1,
#           'ticket seller': -1,
#           'find': 2,
#           'rating': 1,
#           'issue': -8.5,
#           'detail': 13,
#           'range': 6,
#           'purchase': 1,
#           'entry price': -1,
#           'option': 4,
#           'entry fee': -3,
#           'money': 8.75,
#           'set': 4,
#           'entrance fee': -4,
#           'size limit': -1,
#           'product': 2,
#           'volume': 3,
#           'gift store': 1,
#           'downside': -7,
#           'list': 2,
#           'cost': 2,
#           'reason': 5,
#           'quantity': 1,
#           'hour limit': -1,
#           'penny': 2,
#           'decide': -1,
#           'rate': 3,
#           'loss': -1,
#           'ship': 2,
#           '12.00': -1,
#           'meter money': -1,
#           'indication': 1,
#           'pittance': -2,
#           'stock': 1,
#           'bad': -1,
#           'refund': 2,
#           'choice': 3,
#           'brand': -1,
#           'museum size': 1,
#           'consider': 0,
#           'paint case': 1,
#           'sale': 1,
#           'scale': 3,
#           'student discount': 1,
#           'ticket price': 2,
#           'gold': 1,
#           'extra': 1,
#           'housing': 2,
#           'end': -2,
#           'plus': 0,
#           'total': 2,
#           'entry student price': 1.5,
#           'real': -1,
#           'minute top': 1,
#           'difference': 1,
#           'dollar': 1,
#           'plumbing issue': -1,
#           'hour investment': 1,
#           'share': 1,
#           'inventory': 1,
#           'add': 2,
#           'buyer': -1,
#           'adult price': 1}),
#  'service': Counter({'time': 137.75,
#           'example': 29,
#           'work': 2871.5,
#           'right': 12,
#           'complaint': -10,
#           'shop': 281.0,
#           'experience': 141,
#           'access': 2,
#           'variety': 93.5,
#           'art work': 90.0,
#           'job': 104.5,
#           'installation': 1,
#           'desk staff': 3,
#           'app': 62,
#           'use': 8,
#           'wife work': 2,
#           'gift shop': 82.0,
#           'personnel': 1,
#           'cloud': -15,
#           'staff': 129.75,
#           "o'keeffe work": 12,
#           'o work': 2,
#           'hour': 56.5,
#           'location': 22,
#           'selection': 78,
#           "o'keefe work": 10,
#           'search': 1,
#           'view': 27.5,
#           'problem': -18,
#           's work': 1,
#           "o'keefe georgia work": 1,
#           'process': 5,
#           'information': 51.75,
#           'day': 20.5,
#           'lifetime work': 1,
#           'line': 8.5,
#           'program': 3,
#           'number': -9.75,
#           'phone': 19,
#           'keefe work': 2,
#           'museum staff': 4,
#           'person': 23,
#           'understanding': 51,
#           's o . work': 2,
#           'resource': 2,
#           'art person': -1,
#           'keeffe work': 1,
#           'event': 2,
#           'reputation': 4,
#           'answer': -1,
#           'time line': 2,
#           'site': 7,
#           'honoring': 2.5,
#           'arrangement': 2,
#           'keeffe o georgia work': 1,
#           'opportunity': 23,
#           'employee': 3,
#           'source': 2,
#           'charge': -1.5,
#           'approach': 4,
#           'start': 2,
#           'museum shop': 20.25,
#           'addition': 14,
#           'design': 4.5,
#           'size cloud': -1,
#           "o'keefes georgia work": 1,
#           'artist work': 9.5,
#           'open': 2,
#           'home': 13,
#           'offering': -1,
#           'facility': 12,
#           'o;keefe work': 1,
#           'volunteer staff': 3,
#           'staff work': 1,
#           'museum app': 1,
#           'gok work': 1,
#           'art okeefe . work': 1,
#           'quality': 6,
#           'independent': 1,
#           'connection': 0,
#           'woman work': 3,
#           'membership': 2,
#           'morning': 3,
#           'today': 3,
#           'ability': 5,
#           'base': 2,
#           'care': 1,
#           'benefit': 6,
#           'school': 0,
#           'machine': -1.5,
#           'rotate work': 1,
#           'expert': 1,
#           'knowledgeable': 1,
#           'system': 0,
#           'station': 1,
#           'management problem': -1,
#           'fe work': 1,
#           'family': 0,
#           'commitment': 3.5,
#           'excellence': 2.5,
#           'okeefe work': 3,
#           'regard': 7,
#           'art -PRON- work': 1,
#           'message': 2,
#           'knowledge': 0,
#           'education': 3,
#           'team': 1.5,
#           'garden plan': 1,
#           'life work': 6,
#           'assortment': 7,
#           'child work': 1,
#           'content': 1,
#           'distribution': 1,
#           'tour leader': 3,
#           'varity': 1,
#           'gain work': 1,
#           'volunteer': 11,
#           'recommendation': 4,
#           'quality work': 1,
#           'advice': 1,
#           'effort': 3,
#           'conservation concern': 0,
#           'protection': -1,
#           'individual': 5,
#           'center': 2,
#           'hassle': -1,
#           'wifi': 5,
#           'privilege': 7,
#           'reservation': 1,
#           'respect': 8,
#           'nm work': 2,
#           'feature': 2,
#           'docent work': 1,
#           'chat': 1,
#           'news': -3,
#           'advantage': 11,
#           'art gayle work': 1,
#           'concern': -2,
#           'community program': 1,
#           'entry charge': 1,
#           'student work': 1,
#           'integrity': 1,
#           "o'keefes work": 4,
#           'inconvenience': -1,
#           'museum person': 1,
#           'tool': 1,
#           'help': 2,
#           'development': 2,
#           'ny work': 1,
#           'oversight': 1,
#           'aid': 2,
#           'establishment': 1,
#           'alternative': 2,
#           'management': 1,
#           'desk': 1,
#           'reception': -1,
#           'fast': -1,
#           'success': 4,
#           'hearing problem': -1,
#           'preparation': 1,
#           's o work': 1,
#           "o'keeffe georgia work": 3,
#           'good': 4,
#           'innovation': 0,
#           'companion work': 1,
#           'necessity': 1,
#           'life artist work': 2,
#           'security': -4,
#           "art o'keefe georgia work": 1,
#           'catalog': -2.25,
#           'organization': 0,
#           'guidance': 1,
#           'voice': -1,
#           'renown': 2,
#           'museum support': 1,
#           'car': 1,
#           'girlfriend work': 1,
#           'return': 2,
#           'service': 3,
#           'air conditioning': 0,
#           'research center': 1,
#           'policy': 1,
#           'notice': 1,
#           'traveler experience': 1,
#           'exchange': -1,
#           'setup': 1,
#           'account': 2,
#           'art expert': 1,
#           'church': 2,
#           'scape city work': 1,
#           'art museum work': 1,
#           'self service': 1,
#           'color selection': 1,
#           'duty military': 1,
#           'hers work': 1,
#           'wifi problem': -1,
#           'realism work': 1,
#           'charcoal work': 1,
#           'easy': 1,
#           'book shop': 1,
#           'creation': 1,
#           'flower work': 2,
#           'briefing': 1,
#           'york work': 1,
#           'mexico work': 1,
#           'gift museum shop': 1,
#           'military': 1,
#           'donation': 1,
#           'background information': 1,
#           'signature work': 2,
#           'marketing': 1,
#           'browser': -1,
#           'prompt': 1,
#           'genius work': 1,
#           'premier': 1,
#           'promotion': -1,
#           'hawaii work': 2,
#           'execution': -1,
#           'advance reservation': -1.5,
#           'public': 1,
#           'yosemite work': 1,
#           'adams work': 1,
#           'lifetime -PRON- work': 1,
#           'city work': 1,
#           "art o'keeffe georgia work": 1,
#           "museum o'keeffe shop": 1,
#           'delivery': 1,
#           'security staff': 2,
#           'relationship': 0,
#           'association': 1,
#           'art community': -1,
#           'improvement': 1,
#           'owner': 1,
#           'understand': -1,
#           'customer': 1,
#           'ask': 1,
#           'library': 1,
#           'georgia work': 1,
#           'survey': 1,
#           'coverage': 1.5,
#           'asset': -1,
#           'property work': 1,
#           'advertising': -1,
#           'proprietor': -1,
#           'ticket agent': -2.25,
#           'dedication': 1,
#           'shop staff': -1,
#           'web site': 1,
#           'control': -1,
#           'website': 1,
#           'mission': 1,
#           'exhibition schedule': 1,
#           'her work': 1,
#           'sound system': -1,
#           'safety': 1,
#           'museum other': -1,
#           'attendee': -1,
#           'brush work': 1}),
#  'misc': Counter({'art': 327.0625,
#           'woman': 134.5,
#           'video': 219.75,
#           'documentary': 17,
#           'minute movie': 4,
#           'exhibit': 172.0,
#           'flower': 41.5,
#           'bit': -3.5,
#           'independence wit': 1,
#           'minute': 10.5,
#           'film': 232.0,
#           'display': 89.5,
#           'husband': 17,
#           'son': 4.5,
#           'piece': 105.5,
#           'locker': 35,
#           'artist': 410.25,
#           'master': 17,
#           'clarity': 1,
#           'section': 10,
#           'cross': 1.5,
#           'genius': 27,
#           'career': 4,
#           'block buster': -1,
#           'movie': 96.5,
#           '-PRON-': 251.5,
#           'body': 8,
#           'collection': 257.25,
#           'cake': 1,
#           'coat rack': 1,
#           'fan': 15,
#           'gallery': 59.5,
#           'painter': 35,
#           'sketchbook': 1,
#           'glare': -3,
#           'manipulation': -1,
#           'keeffe o aficionado': -1.5,
#           'overview': 75,
#           'admission': 22.25,
#           'talent': 59.0,
#           'keefe': 3,
#           'painting': 256.0,
#           'bone': 1,
#           'buck': 1,
#           'notch': 5,
#           'year': 9.0,
#           'context': 10,
#           'jewelry': 2,
#           'art lover': 28,
#           'patience': 2,
#           'character': 6,
#           't': 7,
#           'representation': 34,
#           'kid': 12,
#           'fe': 6,
#           'treat': 8,
#           'mph': -1,
#           'stuff': 20,
#           'art critic': -2,
#           'insight': 71.75,
#           'favorite': 33,
#           "o'keefe": 40,
#           'ruffle': -1,
#           'title': 1,
#           'bench': 3,
#           'yard': 1,
#           'sampling': 25,
#           'museume': 1,
#           'independence': 2,
#           'teenager': 6,
#           'presentation': 39,
#           'artwork': 72.5,
#           'hero': 3,
#           'friend': 8,
#           'security guard': 4,
#           'perfection': 3,
#           'sample': 4,
#           'lady': 23,
#           'color': 22,
#           'mistake': -4,
#           'beginning': 3,
#           'signature perfection': 1,
#           'retrospective': 13,
#           'spectrum': 1,
#           'interview': 3,
#           'milestone': 1,
#           'video presentation': 8,
#           'child': 4,
#           'reproduction': 3,
#           'snake': -1,
#           'remembrance': 1,
#           'goer': 0,
#           'man': -4,
#           'behavior': -1,
#           'minute film': 3.5,
#           'mexicans': 1,
#           'sculpture': 1,
#           'brother': 0,
#           "o'keeffe georgia fan": 1,
#           'respite': 3,
#           'introduction': 51,
#           'masterpiece': 11,
#           'exhibition': 27.5,
#           'mix': 8,
#           'student': 1,
#           'blockbuster': 2,
#           'mexico': 8,
#           'museum guard': 1,
#           'guard': -1.5,
#           'phase': 3,
#           'sneer': -1,
#           'awakening': 1,
#           'bonus': 19.5,
#           'word': 0,
#           'wife': 20.5,
#           'staircase': -1,
#           'freedom': 6,
#           'layout': 10,
#           'bit overkill': -1,
#           'art connoisseur': -2,
#           'span': 4,
#           'fi': 2,
#           'discussion': 3,
#           'bathroom': 5,
#           'granddaughter': 2,
#           'audio': 4.5,
#           'ranch': 5,
#           'punch': -1,
#           'scope': 2,
#           'story': 47,
#           'drawing': 3.5,
#           'timeline': 25,
#           'homage': 3,
#           'keeffe': 5,
#           'daughter': 7,
#           'bias': -1,
#           'georgia': 8,
#           'depression': -1,
#           'legacy': 4,
#           'parking meter': 1,
#           'touch': 12,
#           'o': 1,
#           'download': 2,
#           'daughter artwork': 1,
#           'parking sign': -1,
#           'tad': -1,
#           'overwhelm': -1,
#           'paint': 2,
#           'observer': 2,
#           'vision': 4,
#           'booklet': 1,
#           'distraction': -2,
#           'prize': 1,
#           'dislike': -1,
#           'evolution': 8.0,
#           'bloom': 3,
#           'nonsense': 0,
#           'video projection': -1,
#           'city art': 1,
#           'primer': 2,
#           'iota': 1,
#           "o'keeffe": 32,
#           'comment': 1,
#           'museum lover': 1,
#           'contribution': 18,
#           'frame': 0,
#           'attempt': -1.5,
#           'die': -1.5,
#           'disappointment': -40,
#           'security guy': 1,
#           'guy': 2,
#           'period': 11,
#           'photographer': 22,
#           'portion': 1,
#           'sit': -1,
#           'sculptor': 1,
#           'tribute': 18.5,
#           'picture': 23,
#           'time lover': 1,
#           'object': -9,
#           '-PRON- art': 1,
#           'smiliar': 2,
#           'pattern': -1,
#           'tory': 1,
#           'narration': 2.5,
#           "o'keeffe piece": 1,
#           'breathless': 1,
#           'boggle': 1,
#           'art hero': 1,
#           'eye': 6.5,
#           'question': 4,
#           'progress': 4,
#           'tween kid': 1,
#           'skill': 7,
#           'adult daughter': 2,
#           'spaced': 1,
#           'print': 19,
#           'tourist trap': -2,
#           'luck': -1,
#           'signage': 2.5,
#           'parent': -1,
#           'buzz kill': -1,
#           'photography': 15,
#           'caption': 1,
#           'magic': 2,
#           'diversion': 5,
#           'lover': 15,
#           'foot': -1,
#           'patron saint': 2,
#           'female': -2.25,
#           'wheelchair': 3,
#           'director': 1,
#           'wall': 0,
#           'curation': 1,
#           'wisdom': 1,
#           'coincidence': 1,
#           'washroom': 1,
#           'pairing': 3,
#           'critic': -5,
#           'study': 2,
#           'prelude': 1,
#           'photo': 55.75,
#           'curator': 5,
#           'learning': 1,
#           'surprive': 1,
#           'critter': 1,
#           'notecard': 1,
#           'measure': 1,
#           'heck': 1,
#           'component': 1,
#           'copy': 1,
#           'exhaustion': -1,
#           'hand': 1.5,
#           'adult': 0,
#           'difficulty': -5,
#           'didactic': 2,
#           'ghost ranch': 2.5,
#           'introspective': 1,
#           'accomplishment': 5,
#           'lead': 7,
#           'movement': 4,
#           'film presentation': 1,
#           'marker': 2,
#           'reminder': 3,
#           'window': 3,
#           'chronology': 2,
#           'biography': 8,
#           'build': 3,
#           'length': 2,
#           'modernism': 2,
#           'self': 3,
#           'scarf': 2,
#           'photograph': 52.5,
#           'minute preamble': -1,
#           'tidbit': 1,
#           'video clip': 1,
#           'cluster': 1,
#           'member': 2,
#           'lily': 2,
#           'painting book': 1,
#           'admirer': 22,
#           'american': 3,
#           'imho': -1,
#           'death': -15,
#           'mom': 2,
#           'regret': -6,
#           'talk': 10,
#           'giclee': 1,
#           'canvas': 3,
#           'entry': 3,
#           'door': -1,
#           'highlight': 5.5,
#           'explanation': 9.5,
#           'role': -1,
#           'interpretation': 1,
#           'fortune': 2,
#           'souvenir': 6,
#           'majority': 1,
#           'film clip': 2,
#           'connotation': -1,
#           'philosophy': 1,
#           'visite': 1,
#           'myou': 1,
#           "o'keefe enthusiast": 1,
#           'wa exception': 1,
#           'thinking': 2,
#           'keeffe fan': 1,
#           'minute video': 2.5,
#           'fault': 0,
#           'peek': 3,
#           'oil': 7,
#           'deterioration': -1,
#           'damage': -1,
#           'excuse': -3,
#           'shortcoming': -2,
#           'orientation': 2,
#           'spunk': 1,
#           'device': 2,
#           'fame': 3,
#           'limitation': -2,
#           'layer': 1,
#           "o'keefe georgia painting": 1,
#           'lapse': -2,
#           's': -1,
#           'announcement': 1,
#           'fall': -4,
#           'stream': 1,
#           'planning sketch': 1,
#           'greeting': -1,
#           'cousin': 1,
#           'mistrust': -1,
#           'backpack': 1,
#           'research': 0.75,
#           'writing': 1,
#           'generation': 1,
#           'grit': -1,
#           'soundbite': 1,
#           '13': -1,
#           '-PRON- story': 1,
#           'teen boy': 1,
#           'merit': 1,
#           'portrait': 6,
#           'sketch': 7,
#           'memento': 1,
#           'sketch pad': 2,
#           'headphone': 3.5,
#           'big': 1,
#           'sundays': 1,
#           'intoductory video': 1,
#           'opinion': 1,
#           'intro video': 1,
#           'sketching': 1,
#           'clip board': 1,
#           'tween girl': 1,
#           'showing': 2,
#           'fanatic': 1,
#           'spread': 1,
#           'drawback': -2,
#           'legend': 1,
#           'reverence': 1,
#           'book': 17.5,
#           'place imprint': 1,
#           'frontierswoman': 1,
#           'time lapse': -5,
#           'keefe o admirer': 1,
#           'abiquiu': 2,
#           'narrative': 3,
#           'documentary film': 1,
#           'scratch': -1,
#           'conservator': 1,
#           'commentary': 3,
#           'morning glory': 2,
#           'perseverance': 2,
#           'lay': 3,
#           'inclusion': 3,
#           'birthday': 1,
#           'carrot cake': 1,
#           'stroke': 3,
#           'myth': -3,
#           'consignment gallery': 1,
#           'adobe': 1,
#           'harm': -2,
#           'pioneer': 1,
#           'stieglitz': 1,
#           'week': 0,
#           'boost': 1,
#           'day proposition': -1,
#           'struggle': -1,
#           'controversy': -1,
#           'waste': -11.5,
#           'pen': 0,
#           'ear bud': 2,
#           'min': 1,
#           'synthesis': 1,
#           'monument': 1,
#           'misconception': -5,
#           'sinage': 1,
#           "o'keeffe death": -1,
#           'video introduction': 1,
#           'cause': 1,
#           'aspiration': 2,
#           'angle': 2,
#           'standpoint': -1,
#           'museum collection': 2,
#           'studio': 5,
#           'learn': 8,
#           'skyscraper': 1,
#           'london': 1,
#           'altitude sickness': -1,
#           'visionary': 3,
#           'field': 2,
#           'degeneration': -5,
#           'accolade': 1,
#           'canvass': 1,
#           "o'keefe fanatic": -1,
#           'supplement': 1,
#           'summary': 4,
#           'depiction': 4,
#           '-PRON- eye': 1,
#           'lapse time film': 1,
#           'shawl': 1,
#           'painting skill': 1,
#           'film documentary': 1,
#           'standout': 2,
#           'expression': 1,
#           "art o'keeffe lover": 1,
#           'grandkid': 2,
#           'image': 8,
#           'shame': -9,
#           'hit': 1,
#           'time admirer': 2,
#           'mount': 1,
#           'award': 2,
#           'poppy': 2,
#           'postcard': 2,
#           'girl': 2,
#           'exposition': 1,
#           'sf': 1,
#           '14': -1,
#           'perk': 1,
#           'arc': 1,
#           'achievement': 2,
#           'pretense': -2,
#           'bunch': 1,
#           'vibration': -1,
#           'colour': 1,
#           'commotion': -1,
#           'adams genius': 1,
#           'barrier': -1,
#           'art purist': 1,
#           'embarrassment': -3,
#           'calendar': 1,
#           'parking street meter': 1,
#           'smile': 1,
#           'block': 4,
#           'accompaniment': 1,
#           'disrespect': -2,
#           'type': 1,
#           'note': 1,
#           'glass': -1.5,
#           'human': 1,
#           'okeefe': 2,
#           'datum': 1,
#           'sign': 2,
#           'wit': 1,
#           'hollyhock': 1,
#           'anniversary week': 1,
#           'keeper': 0,
#           'history lesson': 1,
#           'lesson': 2,
#           'artisy fellow': -1,
#           'perpspective': 1,
#           'exibit': 2,
#           'timing': 0,
#           'shift': 1,
#           'jesse': -2,
#           'jane': -1,
#           'hype': -3,
#           'sister': 3,
#           'thank': 4,
#           'run': 2,
#           'parent kid': 1,
#           'audioguide': 3,
#           'cappuccino': 1,
#           'retrospect': 1,
#           'narration tape': 1,
#           'nest': 1,
#           'framing': 1,
#           'dozen': -1,
#           'seat': 1,
#           'endowment': 1,
#           "o'keeffe . art": -1,
#           'bust': -1,
#           'nm hero': 1,
#           'lifetime': 2,
#           'dvm': 1,
#           'veteran': 1,
#           'intro': 6.25,
#           'second': 0,
#           'miss': -3,
#           'definition': 2,
#           'toddler': -2,
#           'spacing': 1,
#           'preference': 1,
#           'disappoint': -1,
#           'grandchild': 1,
#           "o'k g fan": 1,
#           'afficianado': 1,
#           'november': -1,
#           'christmas': -1,
#           'blank': 1,
#           'pastel': 1,
#           '10': 1,
#           'showcase': 3,
#           'flower scale painting': 1,
#           'watercolor': 3,
#           'cow skull': -1,
#           'artsist': 1,
#           'ground breaking': -1,
#           'acrylic': 4.375,
#           'hour movie': -1,
#           'museum display': 1,
#           'prospective': 1,
#           'criticism': -6,
#           'docent lead': 1,
#           'meter': -1,
#           'fancy': 1,
#           'doc': 1,
#           "o''keeffe fan": 2.25,
#           'homecoming': 1,
#           'reading': 1,
#           'experimentation': 2,
#           'maturity': 1,
#           'bud': 1,
#           'color water painting': 2,
#           "o'keefe lover": 1,
#           'visual': 1,
#           'nm': 3,
#           'maze': -1,
#           'misunderstanding': -1,
#           'pigeon holing': -1,
#           'class': 2,
#           "o'keeffe . masterpiece": 1,
#           'half': 2,
#           'sized': 1,
#           'feed': 3,
#           'ignorance': -1,
#           'criminal': -1,
#           'death glare': -2,
#           'grandmother': 1,
#           'willingness': 1.5,
#           'explanation plaque': 1,
#           'moy contribution': 1,
#           'array': 6,
#           'preview': 1,
#           'immersion': 1,
#           'actor': 1,
#           'hair': 1,
#           'card': 4,
#           'versatility': 1,
#           'rotation': 0,
#           'goose bump': -1,
#           'memory': 1,
#           'era': -2,
#           'jimson weed': -1,
#           'favor': 6,
#           'providence': 1,
#           'flower bloom': 1,
#           "o'keeffe bug": -1,
#           'group': 6.5,
#           'texas': 1,
#           'trouble': -2,
#           'courage': 4,
#           'teen': 0,
#           'sucker': -1,
#           'ripoff': -1,
#           'pretension': 1,
#           'security threat': -1,
#           'flag': -1,
#           '. badge': -1,
#           'threat': -2,
#           'security measure': -1,
#           'disservice': -2,
#           'companion': 2,
#           'hanging': 1,
#           'bartender': 2,
#           'hour menu': 1,
#           'bakery': 1,
#           'poster': 3,
#           'surpise': 1,
#           'document': 1,
#           'staff member': 3,
#           'grace': 1,
#           'state': 2,
#           'inch': 2,
#           'peopler': 1,
#           'subject': 6,
#           'boy': 1,
#           'deet': 1,
#           'c.': 1,
#           'classic': 3,
#           'motivation': 1,
#           'stage': 2,
#           'technique': 2,
#           "o'keeffe fan": -1,
#           'downloadable': 2,
#           'price tag': -2,
#           'enthusiast': 2,
#           'admission lady': -1,
#           'life story': 3,
#           'fit': 2,
#           'art benefactor': 1,
#           'art collection': 2,
#           'dish': 2,
#           'meat': 2,
#           'ticket taker': -1,
#           'imbecile': 1,
#           'nose': -2,
#           'hometown tribute': 1,
#           'life -PRON- story': 1,
#           'foe': 1,
#           'art teacher': 1,
#           'artifact': 2,
#           'restroom': 3.5,
#           'trick': -1,
#           'testimony': 1,
#           'divide': 1,
#           'nude': 1,
#           'obsession': 0,
#           'praise': 3,
#           'multimedia': 1,
#           'shadow': 2,
#           'portrait self nude': -1,
#           'serenity': 1,
#           'stew': -1,
#           'anniversary': 1,
#           'white': 1,
#           'historian': 1,
#           'richness': 1,
#           'goodness': 3,
#           'coolection': -1,
#           'admittance': 1,
#           'foundation': 1,
#           'width': 1,
#           'senseless': -1,
#           'paper': 1,
#           "o'keeffee": 2,
#           'maverick': 1,
#           'live': -2.25,
#           'original': 2,
#           'hunt': 1,
#           'tragic': -1,
#           'progression': 1,
#           'precursor': 1,
#           'okeefe lover': 1,
#           'grasp': 1,
#           'youth': 1,
#           'informative': 1,
#           'viewing': 0,
#           'art enthusiast': 0,
#           'influential': 1,
#           'colleague': 1,
#           'scarcity': -2,
#           'slideshow': 1,
#           'intro movie': 2,
#           'bracelet': 1,
#           'paucity': -2,
#           'cryin': -1,
#           'int': 1,
#           'pc': 1,
#           "o'keefe painting": 0,
#           'magazine': 1,
#           'footage': 2,
#           'unknown': -1,
#           'rendition': 1,
#           'wing': -1,
#           'contemplation': 2,
#           '18': -1,
#           'video documentary': 2.5,
#           'ear': 1,
#           'plug': 1,
#           'loop': 1,
#           '25': -1,
#           'impediment': 1,
#           'licensing infringement': -1,
#           'newyork': 1,
#           'bill': 1,
#           'museum fatigue': -1,
#           'gaze': 1,
#           "o'keefe hype": -1,
#           's painting': 1,
#           "o'keeffe collection": -1,
#           'outsider': -1,
#           'face': -1,
#           'op': 1,
#           'wrong': -1,
#           'bookstore': 2,
#           'fuss': -1,
#           'massage': 1,
#           'term ripoff': -1,
#           'exaggeration': -1,
#           'sentence': 1,
#           'fiilm': 1,
#           'meaning': 1,
#           'hardship': -1,
#           'conformist': 1,
#           'cherry blossom': 1,
#           'turkey': -1,
#           'ending': 1,
#           "o'keeffe fanatic": -1.5,
#           "o'keefe georgia admirer": 3.75,
#           'picture photo': 1,
#           '-PRON- painting': 0,
#           'edge': 0,
#           'video production': -1,
#           'production': 1,
#           'exemplar': 1,
#           'compilation': 1,
#           'hunt book': 1,
#           'hearing': 3.25,
#           'fanfare': 1,
#           'blessing': 1,
#           'earbud': 1,
#           'quibble': -1,
#           'chalk': -1,
#           'devotion': 1,
#           'jam': -2,
#           'bored': -1,
#           'pic': 1,
#           'recap': 1,
#           'mock': -2,
#           'p.m.': 1,
#           'glory': 1,
#           'jewlry': 1,
#           'hackman': 1,
#           'know': 1,
#           'space limitation': -1,
#           'minute documentary': 1,
#           'thinker': 1,
#           'lecture': 5,
#           'charcoal': 1,
#           'appeal': 2,
#           'gallery collection': 1,
#           'horde': -2,
#           'receptionist': 1,
#           'vice': -1,
#           'audacity': -1,
#           'bother': -1,
#           'weakness': 1,
#           'absence': -1,
#           'viewer': 2,
#           'notepad': 1,
#           'method': 1,
#           'demostration': 1,
#           'expansion': 1,
#           'hook': 1,
#           'pop': 1,
#           'shoppe': 1,
#           "o'keeffe art": -1,
#           "o'keeffe painting": 1,
#           'installment': 1,
#           'easel': 1,
#           'napkin': -1,
#           'covarrubias exhibit': 1,
#           'coat': -1,
#           'covarrubias': 1,
#           'hawaii': 1,
#           'represetion': 1,
#           'wasa': 1,
#           'exercise': 1,
#           'santafe': 1,
#           'usher': 1,
#           'atmmosphere': 1,
#           'direction': 1,
#           'laugh': 1,
#           '1': 1,
#           '90': -1,
#           'age': 2,
#           'rule': -1,
#           'docent lecture': 1,
#           'museum goer': -1,
#           'giftshop': 1,
#           'georgia lover': 1,
#           'video biography': 1,
#           'movie clip': 1,
#           'adams exhibit': 3,
#           'dismay': -1,
#           'pathway': 1,
#           'boundary': -1,
#           '-PRON- collection': 1,
#           '12per adult': 1,
#           'spelling': 1,
#           'decorating skill': 0,
#           "o'keefes art": 1,
#           'aunt': 1,
#           'packet': 1,
#           "o'kefe": 1,
#           'replica': 1,
#           'dimension': 2,
#           'revelation': 3,
#           'hour talk': 1,
#           'writer': 1,
#           'hug': 1,
#           'snap': 2,
#           'core': 0,
#           'brand bakery': 1,
#           'hawaii exhibit': 1,
#           'father': 0,
#           'farmer': 1,
#           'adams photo': 1,
#           'video short': 1,
#           "o'keeefe": 1,
#           'films': 1,
#           'head': -1,
#           'statement': -1,
#           'clerk': 1,
#           'belonging': 1,
#           "o'keeffe admirer": 1,
#           '-PRON- talent': 1,
#           'photo op': -3.75,
#           'goody': 1,
#           'adversity': -1,
#           'brush': 1,
#           'videography': 1,
#           'hawaii year': 1,
#           'opening movie': 1,
#           'squabble': -1,
#           'warning': -1,
#           'wish': 1,
#           'century master': 2,
#           'irritation': -1,
#           'standing': 1,
#           'adams': -1,
#           'nyc period': 0,
#           'popularity boom': 1,
#           'aside': -1,
#           'scholarship': 1,
#           'gesture': 2,
#           'art gallery': -1,
#           'swirls': 1,
#           'fridays': 1,
#           'grant': 1,
#           'bomb': -1,
#           'vista': 1,
#           'brochure': -1,
#           'asthma': -1,
#           'caretaker': -1,
#           'spade': -1,
#           'key': -1,
#           'clara': 1,
#           'restriction': -1,
#           'keeffe o sculpture': 1,
#           'wild': -1,
#           'abstract': 1,
#           'color shame': -1,
#           'abq': 1,
#           'quarter': 1,
#           'shop lady': 1,
#           'artiist': 1,
#           "o'keeffe georgia gallery": 1,
#           'letter': 2,
#           'biting': -1,
#           'kid teen': 1,
#           'museum showing': -1,
#           'ln': 1,
#           'etiquette': -1,
#           'reviewer': 1,
#           'flower painting': 2,
#           'slot': 1,
#           'g': 1,
#           'photography gallery': 1,
#           'okeeffe fan': -1,
#           'catalogue raisonn': -1,
#           'marriage': 1,
#           'museaum': 1.5,
#           'odor': -1,
#           'trap': -1,
#           'urinalysis': -1,
#           'drawer': 1,
#           'landscape painting': 1,
#           'icon': 2,
#           'step': 1,
#           'scholar': 1,
#           'van': 1,
#           'breadth': -1,
#           'stieglitz photo': 1,
#           'framework': 1,
#           'mon': -1,
#           'shope': 1,
#           'becuse': 1,
#           "don't": -1,
#           'entree': 0,
#           'narrator': 1,
#           'room video': -1,
#           'clip': 1,
#           "o'keeffe exhibit": 1,
#           'testament': 1,
#           'vignette': 1,
#           'read': 1,
#           'furniture': 1,
#           'wrought': -1.5,
#           'beam ceiling': -1.5,
#           'ceiling': 1,
#           'leibowitz annie display': 1.5,
#           "o'keeffe display": 1,
#           'momento': 1,
#           'leibovitz collection': 1,
#           'mother': 1,
#           'exterior': 1,
#           'tent': -1,
#           "o'keeff'e masterpiece": 1,
#           'rate collection': -1,
#           'bore': -1,
#           'table vignette': 1,
#           'kitchen': 1,
#           'overkill': -1,
#           'radiator': -1,
#           'annecdote': 1,
#           'cursive': -1,
#           'perfume': -1,
#           'b.s': -1,
#           'preservation': 1,
#           'board': 1,
#           'snack': 1,
#           'apple': 2,
#           'wideness': 1,
#           'advocate': 1,
#           'shape': -1,
#           'short': 1,
#           'gift show': 1,
#           'joke': -2,
#           'quotation': 1,
#           'saint': -1,
#           'mess': -1,
#           'docent talk': 1,
#           'annoyance': -1,
#           "o'keeffe lover": 1,
#           'dirt': -2,
#           'floral': 1,
#           'paper copy': 1,
#           'abstraction': 1,
#           'ironing sears mangle': -1,
#           'curated': 1,
#           'indifference': -2,
#           'condescending': -2,
#           'output': 1,
#           'apreciation': 1,
#           'soda jerk': -1,
#           'rip': -1,
#           'skull': 1,
#           'museum art supporter': 1,
#           'imperfection': -1,
#           'museum art lover': 1,
#           'friday': 1,
#           'purse': 1,
#           'waffle': 1,
#           'bellinis': 1.5,
#           'champane': 1.5,
#           'error': -1,
#           'souviener': -1,
#           'loyalist': 1,
#           'mold': -1,
#           'conference': 1,
#           'refuge': 1,
#           'pictures': 1,
#           'represention': 1,
#           'breakthrough': 1,
#           'grouping': 1,
#           'interviewee': 0,
#           'mark': -1,
#           'stereotype': -1,
#           'directive': 1,
#           'o keeffe': 1,
#           'relevance': 1,
#           'mission statement': 1,
#           'frustration': -1,
#           'weed': 1,
#           'formation': 1,
#           'eyesight': -1,
#           'documentary video': -1.5,
#           'snob': -1,
#           'boredom': -1})}

# %%
import pickle

# pickle the aspect terms and sentiment separately.
# Modify this code for the restaurant of interest.
pickle.dump(aspect_sent, open("GOK_sent.pkl", 'wb'))
pickle.dump(terms_dict, open("GOK_aspects.pkl", 'wb'))

# %%
aspect_sent = pickle.load(open("GOK_sent.pkl", 'rb'))
terms_dict = pickle.load(open("GOK_aspects.pkl", 'rb'))

# %%
import matplotlib.pyplot as plt

# quick visualization
pd.DataFrame(aspect_sent).T.plot(kind='bar')
plt.show()

# %%
from collections import defaultdict

lowest = defaultdict()
highest = defaultdict()
for i in terms_dict:
    if terms_dict[i]:
        highest[i] = terms_dict[i].most_common()[:10]
        lowest[i] = terms_dict[i].most_common()[-10:]

# %%
highest_df = pd.DataFrame(highest)
lowest_df = pd.DataFrame(lowest)

# %%
import six
def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

# %%
render_mpl_table(highest_df, header_columns=0, col_width=4.0)

# %%
render_mpl_table(lowest_df, header_columns=0, col_width=4.0)
